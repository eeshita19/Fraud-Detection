# %% [markdown]
# #  A PROJECT ON FRAUD DETECTION AND ANALYSIS ON TREND OF FRAUD

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # DATA PREPROCESSING

# %%
df=pd.read_csv("Fraud_detection.csv")

# %%
df.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0            0.00      0.0             0.0
# 1  M2044282225             0.0            0.00      0.0             0.0
# 2   C553264065             0.0            0.00      1.0             0.0
# 3    C38997010         21182.0            0.00      1.0             0.0
# 4  M1230701703             0.0            0.00      0.0             0.0
# 5   M573487274             0.0            0.00      0.0             0.0
# 6   M408069119             0.0            0.00      0.0             0.0
# 7   M633326333             0.0            0.00      0.0             0.0
# 8  M1176932104             0.0            0.00      0.0             0.0
# 9   C195600860         41898.0        40348.79      0.0             0.0

# %% [markdown]
# ##### checks none value in dataset

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     1
# newbalanceOrig    1
# nameDest          1
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14246 entries, 0 to 14245
# Data columns (total 11 columns):
# step              14246 non-null int64
# type              14246 non-null object
# amount            14246 non-null float64
# nameOrig          14246 non-null object
# oldbalanceOrg     14246 non-null float64
# newbalanceOrig    14246 non-null float64
# nameDest          14246 non-null object
# oldbalanceDest    14246 non-null float64
# newbalanceDest    14246 non-null float64
# isFraud           14246 non-null float64
# isFlaggedFraud    14246 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
#df  (TO CHECK DF )

# %%
df.corr()
# Out:
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.040961      -0.065173       -0.065322
# amount          0.040961  1.000000       0.092782        0.062145
# oldbalanceOrg  -0.065173  0.092782       1.000000        0.996683
# newbalanceOrig -0.065322  0.062145       0.996683        1.000000
# oldbalanceDest -0.005285  0.362895       0.196803        0.203862
# newbalanceDest  0.033043  0.459616       0.148137        0.150776
# isFraud        -0.024286  0.133739      -0.005359       -0.027849
# isFlaggedFraud       NaN       NaN            NaN             NaN
#
#                 oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# step                 -0.005285        0.033043 -0.024286             NaN
# amount                0.362895        0.459616  0.133739             NaN
# oldbalanceOrg         0.196803        0.148137 -0.005359             NaN
# newbalanceOrig        0.203862        0.150776 -0.027849             NaN
# oldbalanceDest        1.000000        0.908342 -0.018103             NaN
# newbalanceDest        0.908342        1.000000 -0.009828             NaN
# isFraud              -0.018103       -0.009828  1.000000             NaN
# isFlaggedFraud             NaN             NaN       NaN             NaN

# %%
df_new=df.drop(["nameOrig","nameDest"],axis=1)

# %%
df_new
# Out:
#        step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 0         1   PAYMENT     9839.64      170136.00       160296.36
# 1         1   PAYMENT     1864.28       21249.00        19384.72
# 2         1  TRANSFER      181.00         181.00            0.00
# 3         1  CASH_OUT      181.00         181.00            0.00
# 4         1   PAYMENT    11668.14       41554.00        29885.86
# 5         1   PAYMENT     7817.71       53860.00        46042.29
# 6         1   PAYMENT     7107.77      183195.00       176087.23
# 7         1   PAYMENT     7861.64      176087.23       168225.59
# 8         1   PAYMENT     4024.36        2671.00            0.00
# 9         1     DEBIT     5337.77       41720.00        36382.23
# 10        1     DEBIT     9644.94        4465.00            0.00
# 11        1   PAYMENT     3099.97       20771.00        17671.03
# 12        1   PAYMENT     2560.74        5070.00         2509.26
# 13        1   PAYMENT    11633.76       10127.00            0.00
# 14        1   PAYMENT     4098.78      503264.00       499165.22
# 15        1  CASH_OUT   229133.94       15325.00            0.00
# 16        1   PAYMENT     1563.82         450.00            0.00
# 17        1   PAYMENT     1157.86       21156.00        19998.14
# 18        1   PAYMENT      671.64       15123.00        14451.36
# 19        1  TRANSFER   215310.30         705.00            0.00
# 20        1   PAYMENT     1373.43       13854.00        12480.57
# 21        1     DEBIT     9302.79       11299.00         1996.21
# 22        1     DEBIT     1065.41        1817.00          751.59
# 23        1   PAYMENT     3876.41       67852.00        63975.59
# 24        1  TRANSFER   311685.89       10835.00            0.00
# 25        1   PAYMENT     6061.13         443.00            0.00
# 26        1   PAYMENT     9478.39      116494.00       107015.61
# 27        1   PAYMENT     8009.09       10968.00         2958.91
# 28        1   PAYMENT     8901.99        2958.91            0.00
# 29        1   PAYMENT     9920.52           0.00            0.00
# ...     ...       ...         ...            ...             ...
# 14216     8  TRANSFER  1009197.38        9675.00            0.00
# 14217     8   PAYMENT     6191.55           0.00            0.00
# 14218     8   CASH_IN   357964.68       16352.00       374316.68
# 14219     8   PAYMENT    10524.53      688924.00       678399.47
# 14220     8  CASH_OUT   142195.00       62493.00            0.00
# 14221     8   PAYMENT     5989.49     1564906.65      1558917.17
# 14222     8   PAYMENT     1042.19     1558917.17      1557874.98
# 14223     8   PAYMENT    11434.60     1557874.98      1546440.37
# 14224     8   PAYMENT     4376.88         853.00            0.00
# 14225     8   CASH_IN    28785.83       20964.00        49749.83
# 14226     8   PAYMENT     2971.67       12372.00         9400.33
# 14227     8   PAYMENT     1513.97       23882.00        22368.03
# 14228     8   PAYMENT     1828.23       10013.00         8184.77
# 14229     8   PAYMENT    13007.44        8184.77            0.00
# 14230     8   PAYMENT     4765.43        3172.00            0.00
# 14231     8   PAYMENT     1835.41       20578.00        18742.59
# 14232     8   PAYMENT    14031.52       18742.59         4711.08
# 14233     8   PAYMENT     1146.30      177968.00       176821.70
# 14234     8  CASH_OUT   360004.00        4343.00            0.00
# 14235     8  CASH_OUT     3416.57        2054.00            0.00
# 14236     8   PAYMENT      324.01        3282.00         2957.99
# 14237     8   PAYMENT    11502.82      140341.00       128838.18
# 14238     8  CASH_OUT   406907.39       50257.00            0.00
# 14239     8  CASH_OUT   370284.45       64481.00            0.00
# 14240     8  TRANSFER   316035.90       32835.00            0.00
# 14241     8   PAYMENT    35108.12           0.00            0.00
# 14242     8   PAYMENT    20924.47       18265.00            0.00
# 14243     8  CASH_OUT    75244.54       38369.00            0.00
# 14244     8   PAYMENT     3074.36       10242.00         7167.64
# 14245     8   PAYMENT    11465.21          38.00            0.00
#
#        oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                0.00            0.00      0.0             0.0
# 1                0.00            0.00      0.0             0.0
# 2                0.00            0.00      1.0             0.0
# 3            21182.00            0.00      1.0             0.0
# 4                0.00            0.00      0.0             0.0
# 5                0.00            0.00      0.0             0.0
# 6                0.00            0.00      0.0             0.0
# 7                0.00            0.00      0.0             0.0
# 8                0.00            0.00      0.0             0.0
# 9            41898.00        40348.79      0.0             0.0
# 10           10845.00       157982.12      0.0             0.0
# 11               0.00            0.00      0.0             0.0
# 12               0.00            0.00      0.0             0.0
# 13               0.00            0.00      0.0             0.0
# 14               0.00            0.00      0.0             0.0
# 15            5083.00        51513.44      0.0             0.0
# 16               0.00            0.00      0.0             0.0
# 17               0.00            0.00      0.0             0.0
# 18               0.00            0.00      0.0             0.0
# 19           22425.00            0.00      0.0             0.0
# 20               0.00            0.00      0.0             0.0
# 21           29832.00        16896.70      0.0             0.0
# 22           10330.00            0.00      0.0             0.0
# 23               0.00            0.00      0.0             0.0
# 24            6267.00      2719172.89      0.0             0.0
# 25               0.00            0.00      0.0             0.0
# 26               0.00            0.00      0.0             0.0
# 27               0.00            0.00      0.0             0.0
# 28               0.00            0.00      0.0             0.0
# 29               0.00            0.00      0.0             0.0
# ...               ...             ...      ...             ...
# 14216        37530.00      2226811.03      0.0             0.0
# 14217            0.00            0.00      0.0             0.0
# 14218        16322.00            0.00      0.0             0.0
# 14219            0.00            0.00      0.0             0.0
# 14220        10134.00       388853.85      0.0             0.0
# 14221            0.00            0.00      0.0             0.0
# 14222            0.00            0.00      0.0             0.0
# 14223            0.00            0.00      0.0             0.0
# 14224            0.00            0.00      0.0             0.0
# 14225        67576.15        38790.31      0.0             0.0
# 14226            0.00            0.00      0.0             0.0
# 14227            0.00            0.00      0.0             0.0
# 14228            0.00            0.00      0.0             0.0
# 14229            0.00            0.00      0.0             0.0
# 14230            0.00            0.00      0.0             0.0
# 14231            0.00            0.00      0.0             0.0
# 14232            0.00            0.00      0.0             0.0
# 14233            0.00            0.00      0.0             0.0
# 14234            0.00        36350.43      0.0             0.0
# 14235         1035.00            0.00      0.0             0.0
# 14236            0.00            0.00      0.0             0.0
# 14237            0.00            0.00      0.0             0.0
# 14238      4521916.40      6191938.31      0.0             0.0
# 14239        22612.00     10862988.56      0.0             0.0
# 14240            0.00       312166.92      0.0             0.0
# 14241            0.00            0.00      0.0             0.0
# 14242            0.00            0.00      0.0             0.0
# 14243          167.00            0.00      0.0             0.0
# 14244            0.00            0.00      0.0             0.0
# 14245            0.00            0.00      0.0             0.0
#
# [14246 rows x 9 columns]

# %% [markdown]
# # DATA VISUALISATION

# %%
sns.heatmap(df_new.corr(),annot=True)

# %%
df_new.drop(['isFlaggedFraud'],inplace=True,axis=1)

# %%
#df_new

# %%
from sklearn import preprocessing

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14246 entries, 0 to 14245
# Data columns (total 8 columns):
# step              14246 non-null int64
# type              14246 non-null object
# amount            14246 non-null float64
# oldbalanceOrg     14246 non-null float64
# newbalanceOrig    14246 non-null float64
# oldbalanceDest    14246 non-null float64
# newbalanceDest    14246 non-null float64
# isFraud           14246 non-null float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1001.7+ KB

# %%
df_new.corr()
# Out:
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.040961      -0.065173       -0.065322
# amount          0.040961  1.000000       0.092782        0.062145
# oldbalanceOrg  -0.065173  0.092782       1.000000        0.996683
# newbalanceOrig -0.065322  0.062145       0.996683        1.000000
# oldbalanceDest -0.005285  0.362895       0.196803        0.203862
# newbalanceDest  0.033043  0.459616       0.148137        0.150776
# isFraud        -0.024286  0.133739      -0.005359       -0.027849
#
#                 oldbalanceDest  newbalanceDest   isFraud
# step                 -0.005285        0.033043 -0.024286
# amount                0.362895        0.459616  0.133739
# oldbalanceOrg         0.196803        0.148137 -0.005359
# newbalanceOrig        0.203862        0.150776 -0.027849
# oldbalanceDest        1.000000        0.908342 -0.018103
# newbalanceDest        0.908342        1.000000 -0.009828
# isFraud              -0.018103       -0.009828  1.000000

# %%
df_new.drop(['newbalanceDest','oldbalanceOrg'],inplace=True,axis=1)

# %%
df_new.tail(12)
# Out:
#        step  type     amount  newbalanceOrig  oldbalanceDest  isFraud
# 14234     8     2  360004.00            0.00             0.0      0.0
# 14235     8     2    3416.57            0.00          1035.0      0.0
# 14236     8     0     324.01         2957.99             0.0      0.0
# 14237     8     0   11502.82       128838.18             0.0      0.0
# 14238     8     2  406907.39            0.00       4521916.4      0.0
# 14239     8     2  370284.45            0.00         22612.0      0.0
# 14240     8     3  316035.90            0.00             0.0      0.0
# 14241     8     0   35108.12            0.00             0.0      0.0
# 14242     8     0   20924.47            0.00             0.0      0.0
# 14243     8     2   75244.54            0.00           167.0      0.0
# 14244     8     0    3074.36         7167.64             0.0      0.0
# 14245     8     0   11465.21            0.00             0.0      0.0

# %%
df_new.describe()
# Out:
#                step        amount  newbalanceOrig  oldbalanceDest  \
# count  14246.000000  1.424600e+04    1.424600e+04    1.424600e+04
# mean       5.036923  1.118877e+05    8.107136e+05    8.411336e+05
# std        2.463073  2.805248e+05    2.059984e+06    2.528174e+06
# min        1.000000  2.390000e+00    0.000000e+00    0.000000e+00
# 25%        2.000000  4.584905e+03    0.000000e+00    0.000000e+00
# 50%        6.000000  1.286530e+04    8.216325e+03    0.000000e+00
# 75%        7.000000  1.218946e+05    1.294173e+05    2.641427e+05
# max        8.000000  1.000000e+07    1.301050e+07    2.093759e+07
#
#             isFraud
# count  14246.000000
# mean       0.005475
# std        0.073794
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
Y=df_new["isFraud"]

# %%
#Y

# %%
DF=df_new.replace("PAYMENT",0)
DF1=DF.replace("CASH_IN",1)
df=DF1.replace("CASH_OUT",2)
df1_new=df.replace("TRANSFER",3)
df2_new=df1_new.replace("PAYMENT",4)
df_new=df2_new.replace("DEBIT",5)

# %%
df_new.head()
# Out:
#    step  type    amount  newbalanceOrig  oldbalanceDest  isFraud
# 0     1     0   9839.64       160296.36             0.0      0.0
# 1     1     0   1864.28        19384.72             0.0      0.0
# 2     1     3    181.00            0.00             0.0      1.0
# 3     1     2    181.00            0.00         21182.0      1.0
# 4     1     0  11668.14        29885.86             0.0      0.0

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14246 entries, 0 to 14245
# Data columns (total 6 columns):
# step              14246 non-null int64
# type              14246 non-null int64
# amount            14246 non-null float64
# newbalanceOrig    14246 non-null float64
# oldbalanceDest    14246 non-null float64
# isFraud           14246 non-null float64
# dtypes: float64(4), int64(2)
# memory usage: 779.1 KB

# %%
X=df_new.drop(["isFraud"],axis=1)

# %%
#X

# %%
plt.figure(figsize=(10,8))
bx =sns.boxplot(x= "amount",data = X )
bx.set_title("Boxplot")
plt.show()

# %%
fig,ax=plt.subplots()
print(fig)
print(ax)
ax.violinplot(X["step"],vert=False)
plt.show()
# Out:
# Figure(432x288)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # Data training

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler(feature_range=(0,1))
rescaledX=scaler.fit_transform(X)
rescaledX
# Out:
# C:\Users\EESHITA\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# array([[0.00000000e+00, 0.00000000e+00, 9.83725235e-04, 1.23205354e-02,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.86189044e-04, 1.48992859e-03,
#         0.00000000e+00],
#        [0.00000000e+00, 6.00000000e-01, 1.78610043e-05, 0.00000000e+00,
#         0.00000000e+00],
#        ...,
#        [1.00000000e+00, 4.00000000e-01, 7.52421680e-03, 0.00000000e+00,
#         7.97608607e-06],
#        [1.00000000e+00, 0.00000000e+00, 3.07197073e-04, 5.50911838e-04,
#         0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 1.14628227e-03, 0.00000000e+00,
#         0.00000000e+00]])

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
logit=linear_model.LogisticRegression(C=1e10,max_iter=1e5)
logit.fit(X_train,Y_train)
# Out:
# C:\Users\EESHITA\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=10000000000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100000.0,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
logit.score(X_test,Y_test)
# Out:
# 0.9957894736842106

# %%
logit.score(X_train,Y_train)
# Out:
# 0.9942962442962443

# %%
predictions = logit.predict(X_test)
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test,predictions))
# Out:
# [[2838    0]
#  [  12    0]]

# %% [markdown]
# # PAIRPLOTS

# %%
sns.pairplot(X_train[["step","type","amount","newbalanceOrig","oldbalanceDest"]],diag_kind='kde',hue='type')
# Out:
# C:\Users\EESHITA\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\EESHITA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\EESHITA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\EESHITA\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
logit.predict([[1,2,10000,16296.36,0.0]])
# Out:
# array([0.])

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2838
#          1.0       0.00      0.00      0.00        12
#
#    micro avg       1.00      1.00      1.00      2850
#    macro avg       0.50      0.50      0.50      2850
# weighted avg       0.99      1.00      0.99      2850
# C:\Users\EESHITA\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\EESHITA\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\EESHITA\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
